# %% [markdown]
# ### Name:Sachit kshirsagar

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('data1.xlsx')

# %%
df
# Out:
#      Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0         2012.916667       32.0                                  84.87882
# 1         2012.916667       19.5                                 306.59470
# 2         2013.583333       13.3                                 561.98450
# 3         2013.500000       13.3                                 561.98450
# 4         2012.833333        5.0                                 390.56840
# ..                ...        ...                                       ...
# 409       2013.000000       13.7                                4082.01500
# 410       2012.666667        5.6                                  90.45606
# 411       2013.250000       18.8                                 390.96960
# 412       2013.000000        8.1                                 104.81010
# 413       2013.500000        6.5                                  90.45606
#
# ...

# %%
df.describe()
# Out:
#        Transaction date   House Age  Distance from nearest Metro station (km)  \
# count        414.000000  414.000000                                414.000000
# mean        2013.148953   17.712560                               1083.885689
# std            0.281995   11.392485                               1262.109595
# min         2012.666667    0.000000                                 23.382840
# 25%         2012.916667    9.025000                                289.324800
# 50%         2013.166667   16.100000                                492.231300
# 75%         2013.416667   28.150000                               1454.279000
# max         2013.583333   43.800000                               6488.021000
#
#        Number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# ...

# %%
df.isna().sum()
# Out:
# Transaction date                            0
# House Age                                   0
# Distance from nearest Metro station (km)    0
# Number of convenience stores                0
# latitude                                    0
# longitude                                   0
# Number of bedrooms                          0
# House size (sqft)                           0
# House price of unit area                    0
# dtype: int64

# %%
new_df=df.corr()

# %%
sns.heatmap(new_df,annot=True)
# Out:
# <AxesSubplot: >

# %%
sns.pairplot(df)

# %% [markdown]
# from the above plots house price is high correlations with following variables
# 1)house age
# 2)distance from nearest metro station
# 3)number of convenience stores
# 4)latitude and longitute
#
# And has low correlations with
# 1)number of bedrooms
# 2)house age
# 3)transaction date

# %% [markdown]
# ## using multiple linear regression analysis

# %% [markdown]
# spliting data

# %%
from sklearn.model_selection import train_test_split

# %%
Y=df['House price of unit area']

# %%
X=df[['House Age','Distance from nearest Metro station (km)','Number of convenience stores']]

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %% [markdown]
# training model

# %%
from sklearn.linear_model import LinearRegression

# %%
Lr=LinearRegression()

# %%
Lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predictions=Lr.predict(x_test)

# %%
y_predictions
# Out:
# array([49.65029483, 43.63418374, 43.25559711, 40.54504643, 30.02253185,
#        42.76115343, 44.05213889, 43.97461726, 28.96883548, 52.53812809,
#        32.01140143, 34.41627326, 34.42500748, 28.94187375, 34.10533955,
#        32.76928696, 42.76994007, 51.05718419, 31.5997044 , 46.23694741,
#         1.60852866, 32.82691283, 46.2087237 , 45.73026011, 16.94793687,
#        40.44963146, 16.92441071, 43.25559711, 38.26129413, 35.62242747,
#        11.97136777, 37.36257399, 40.39127489, 32.33166396, 44.95567886,
#        31.0769121 , 52.71901189, 17.53040182, 45.71069998, 41.24947341,
#        33.5998047 , 40.04322085, 47.25263832, 37.83946884, 43.68586483,
#        48.15307671, 46.43656126, 25.49063651, 51.73010247, 47.00674875,
#        49.65029483, 46.65904428, 39.74781606, 42.97368549, 36.85688572,
#        17.50456128, 37.56697735, 34.42301364, 29.94501022, 43.97461726,
#        33.33396251, 30.25747554, 17.50456128, 12.10015575,  4.59259481,
# ...

# %% [markdown]
# accuracy and errors

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
score=r2_score(y_test,y_predictions)
mse=mean_squared_error(y_test,y_predictions)
rmse=np.sqrt(mse);

# %%
print("r2 score is : ",score)
print("mse is:",mse)
print("rmse is:",rmse)
# Out:
# r2 score is :  0.6489726933106557
# mse is: 58.88825128983575
# rmse is: 7.673868078735505

# %% [markdown]
# ## using random forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random_forest = RandomForestRegressor(n_estimators=100)
random_forest.fit(x_train, y_train)
y_predictions1 = random_forest.predict(x_test)

# %%
score1=r2_score(y_test,y_predictions1)
mse1=mean_squared_error(y_test,y_predictions1)
rmse1=np.sqrt(mse1);

# %%
print("r2 score is : ",score1)
print("mse is:",mse1)
print("rmse is:",rmse1)
# Out:
# r2 score is :  0.7667767240403445
# mse is: 39.12547719116751
# rmse is: 6.255036146271859

# %% [markdown]
# ## using support vector machines

# %%
from sklearn.svm import SVR

# %%
svr = SVR(C=100000)
svr.fit(x_train, y_train)
y_predictions2 = svr.predict(x_test)

# %%
score2=r2_score(y_test,y_predictions2)
mse2=mean_squared_error(y_test,y_predictions2)
rmse2=np.sqrt(mse2);

# %%
print("r2 score is : ",score2)
print("mse is:",mse2)
print("rmse is:",rmse2)
# Out:
# r2 score is :  0.676330296972149
# mse is: 54.298746688897374
# rmse is: 7.368768329164473

# %%
x_labels=['linear regression','randomforest','SVM']

# %%
plt.figure(figsize=(8,8))
sns.barplot(x=x_labels, y=[rmse,rmse1,rmse2],width=0.5)
plt.title("Models' RMSE Scores (Cross-Validated)", size=10)
plt.xticks(rotation=30, size=15)
plt.yticks(ticks=np.arange(0, 8, step=0.3),rotation=30, size=15)
plt.show()
